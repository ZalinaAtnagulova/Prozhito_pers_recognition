# %%
from natasha import NamesExtractor
from collections import defaultdict
import re
from datetime import datetime

# %%
def Make_matches(text):
    ne = NamesExtractor()
    matches = ne(text)
    return matches

# %%
def file_walker(file):
    rows = []
    with open(file, 'r', encoding='utf-8') as f:
        train = f.readlines()
    for line in train:
        line = line.strip('\n')
        sets = line.split(',#')
        for setr in range(len(sets)):
            sets[setr] = sets[setr].strip(',#')
        rows.append(sets)
    return rows

# %%
#notes_beautiful_all.csv лежит тут https://yadi.sk/d/Op6Wgv8V3TxaEC
notes = file_walker('notes_beautiful_all.csv')

# %%
len(notes)
# Out:
# 100

# %%
def Extract_names(notes, all_names):
    for note in notes[1:]:
        cases = defaultdict(int)
        note_names = []
        matches = Make_matches(note[2])
        
        for match in matches:
            first, middle, last, nick = match.fact
            string = ''
            for sec in first, middle, last, nick:
                if sec != None:
                    string += str(sec) + ' '
            note_names.append(string[:-1])
        
        for name in note_names:
            cases[name] += 1
            
        if len(note) >= 4:
            arr = [note[0], note[1], note[3]]
        else:
            arr = [note[0], note[1], "Not known"]
        tups = []
        
        for key in cases:
            tups.append((key, cases[key]))
        arr.append(tups)
        all_names.append(arr)
    return(all_names)

# %%
start_time = datetime.now()
all_names = []
names_all = Extract_names(notes, all_names)
end_time = datetime.now()
print('Duration: {}'.format(end_time - start_time))
# Out:
# Duration: 0:00:06.666315

# %%
len(names_all)
# Out:
# 99

# %%
def file_walker(file):
    rows = []
    with open(file, 'r', encoding='utf-8') as f:
        train = f.readlines()
    for line in train:
        line = line.strip('\n')
        sets = line.split(',#')
        for setr in range(len(sets)):
            sets[setr] = sets[setr].strip(',#')
        rows.append(sets)
    return rows

# %%
diary = file_walker('diary.csv')
diaryid_persid = {}
for diar in diary[1:]:
    #print(diar)
    diaryid_persid[diar[0]] = diar[1]

# %%
diaryid_persid
# Out:
# {'"3"': '"4"',
#  '"4"': '"5"',
#  '"5"': '"6"',
#  '"6"': '"7"',
#  '"8"': '"11"',
#  '"9"': '"12"',
#  '"10"': '"13"',
#  '"11"': '"14"',
#  '"12"': '"15"',
#  '"13"': '"16"',
#  '"14"': '"17"',
#  '"15"': '"18"',
#  '"16"': '"19"',
#  '"17"': '"20"',
#  '"18"': '"21"',
#  '"19"': '"22"',
#  '"20"': '"23"',
#  '"21"': '"24"',
#  '"22"': '"25"',
#  '"23"': '"26"',
#  '"24"': '"27"',
#  '"25"': '"28"',
#  '"27"': '"30"',
#  '"28"': '"31"',
#  '"29"': '"32"',
#  '"30"': '"34"',
#  '"31"': '"35"',
#  '"32"': '"36"',
#  '"33"': '"37"',
#  '"34"': '"38"',
#  '"35"': '"39"',
#  '"36"': '"40"',
#  '"37"': '"41"',
#  '"38"': '"42"',
#  '"39"': '"43"',
#  '"40"': '"44"',
#  '"41"': '"45"',
#  '"42"': '"46"',
#  '"43"': '"47"',
#  '"44"': '"48"',
#  '"45"': '"49"',
#  '"46"': '"50"',
#  '"47"': '"51"',
#  '"48"': '"52"',
#  '"49"': '"53"',
#  '"50"': '"54"',
#  '"51"': '"55"',
#  '"52"': '"56"',
#  '"53"': '"57"',
#  '"54"': '"58"',
#  '"55"': '"59"',
#  '"56"': '"60"',
#  '"57"': '"61"',
#  '"58"': '"62"',
#  '"59"': '"63"',
#  '"60"': '"64"',
#  '"61"': '"65"',
#  '"62"': '"66"',
#  '"63"': '"67"',
#  '"64"': '"68"',
#  '"65"': '"69"',
#  '"66"': '"70"',
#  '"67"': '"71"',
#  '"68"': '"72"',
#  '"69"': '"73"',
#  '"70"': '"74"',
#  '"73"': '"77"',
#  '"74"': '"78"',
#  '"75"': '"79"',
#  '"76"': '"80"',
#  '"77"': '"81"',
#  '"78"': '"82"',
#  '"80"': '"83"',
#  '"81"': '"84"',
#  '"82"': '"85"',
#  '"83"': '"33"',
#  '"84"': '"87"',
#  '"85"': '"88"',
#  '"86"': '"89"',
#  '"87"': '"89"',
#  '"88"': '"90"',
#  '"89"': '"91"',
#  '"90"': '"92"',
#  '"91"': '"93"',
#  '"92"': '"94"',
#  '"93"': '"95"',
#  '"94"': '"96"',
#  '"95"': '"97"',
#  '"96"': '"98"',
#  '"97"': '"99"',
#  '"98"': '"100"',
#  '"99"': '"101"',
#  '"100"': '"102"',
#  '"101"': '"103"',
#  '"102"': '"104"',
#  '"103"': '"105"',
#  '"104"': '"106"',
#  '"105"': '"106"',
#  '"106"': '"107"',
#  '"107"': '"108"',
#  '"108"': '"109"',
#  '"109"': '"110"',
#  '"110"': '"112"',
#  '"112"': '"204"',
#  '"113"': '"208"',
#  '"114"': '"207"',
#  '"115"': '"209"',
#  '"116"': '"113"',
#  '"117"': '"210"',
#  '"118"': '"114"',
#  '"119"': '"216"',
#  '"120"': '"115"',
#  '"121"': '"116"',
#  '"122"': '"117"',
#  '"123"': '"118"',
#  '"124"': '"119"',
#  '"125"': '"122"',
#  '"126"': '"121"',
#  '"127"': '"123"',
#  '"128"': '"212"',
#  '"129"': '"124"',
#  '"130"': '"125"',
#  '"131"': '"126"',
#  '"132"': '"127"',
#  '"133"': '"128"',
#  '"134"': '"129"',
#  '"135"': '"130"',
#  '"136"': '"206"',
#  '"137"': '"205"',
#  '"138"': '"131"',
#  '"139"': '"132"',
#  '"140"': '"133"',
#  '"141"': '"134"',
#  '"142"': '"135"',
#  '"143"': '"136"',
#  '"144"': '"137"',
#  '"145"': '"138"',
#  '"146"': '"139"',
#  '"147"': '"140"',
#  '"148"': '"141"',
#  '"149"': '"142"',
#  '"150"': '"143"',
#  '"151"': '"145"',
#  '"152"': '"146"',
#  '"153"': '"147"',
#  '"154"': '"148"',
#  '"155"': '"149"',
#  '"156"': '"150"',
#  '"157"': '"151"',
#  '"158"': '"152"',
#  '"159"': '"153"',
#  '"160"': '"154"',
#  '"161"': '"155"',
#  '"162"': '"156"',
#  '"163"': '"157"',
#  '"164"': '"158"',
#  '"165"': '"159"',
#  '"166"': '"160"',
#  '"167"': '"161"',
#  '"168"': '"162"',
#  '"169"': '"163"',
#  '"170"': '"164"',
#  '"171"': '"166"',
#  '"172"': '"213"',
#  '"173"': '"167"',
#  '"174"': '"168"',
#  '"175"': '"171"',
#  '"176"': '"172"',
#  '"177"': '"173"',
#  '"178"': '"174"',
#  '"179"': '"175"',
#  '"180"': '"176"',
#  '"181"': '"177"',
#  '"182"': '"178"',
#  '"183"': '"165"',
#  '"184"': '"179"',
#  '"185"': '"180"',
#  '"186"': '"181"',
#  '"187"': '"182"',
#  '"188"': '"183"',
#  '"189"': '"184"',
#  '"190"': '"185"',
#  '"191"': '"186"',
#  '"192"': '"187"',
#  '"193"': '"188"',
#  '"194"': '"189"',
#  '"195"': '"190"',
#  '"196"': '"191"',
#  '"197"': '"169"',
#  '"198"': '"170"',
#  '"199"': '"192"',
#  '"200"': '"194"',
#  '"201"': '"195"',
#  '"202"': '"214"',
#  '"203"': '"215"',
#  '"204"': '"197"',
#  '"205"': '"198"',
#  '"206"': '"199"',
#  '"207"': '"200"',
#  '"208"': '"201"',
#  '"209"': '"202"',
#  '"210"': '"203"',
#  '"211"': '"218"',
#  '"212"': '"219"',
#  '"213"': '"220"',
#  '"214"': '"221"',
#  '"215"': '"222"',
#  '"216"': '"223"',
#  '"217"': '"224"',
#  '"218"': '"225"',
#  '"219"': '"226"',
#  '"220"': '"227"',
#  '"221"': '"228"',
#  '"222"': '"229"',
#  '"223"': '"230"',
#  '"224"': '"231"',
#  '"225"': '"232"',
#  '"226"': '"233"',
#  '"227"': '"234"',
#  '"229"': '"236"',
#  '"230"': '"237"',
#  '"231"': '"238"',
#  '"232"': '"239"',
#  '"233"': '"240"',
#  '"234"': '"241"',
#  '"235"': '"242"',
#  '"236"': '"243"',
#  '"237"': '"244"',
#  '"238"': '"245"',
#  '"239"': '"246"',
#  '"240"': '"247"',
#  '"241"': '"248"',
#  '"242"': '"249"',
#  '"243"': '"252"',
#  '"244"': '"254"',
#  '"245"': '"256"',
#  '"248"': '"257"',
#  '"249"': '"258"',
#  '"250"': '"259"',
#  '"251"': '"260"',
#  '"252"': '"261"',
#  '"253"': '"262"',
#  '"254"': '"263"',
#  '"255"': '"264"',
#  '"256"': '"265"',
#  '"257"': '"266"',
#  '"258"': '"267"',
#  '"259"': '"268"',
#  '"260"': '"269"',
#  '"261"': '"270"',
#  '"262"': '"272"',
#  '"271"': '"273"',
#  '"272"': '"274"',
#  '"273"': '"275"',
#  '"274"': '"276"',
#  '"275"': '"277"',
#  '"276"': '"278"',
#  '"277"': '"279"',
#  '"278"': '"280"',
#  '"279"': '"281"',
#  '"280"': '"282"',
#  '"281"': '"283"',
#  '"282"': '"284"',
#  '"283"': '"285"',
#  '"284"': '"286"',
#  '"285"': '"287"',
#  '"286"': '"288"',
#  '"287"': '"289"',
#  '"288"': '"290"',
#  '"289"': '"291"',
#  '"290"': '"292"',
#  '"291"': '"293"',
#  '"292"': '"294"',
#  '"293"': '"295"',
#  '"294"': '"296"',
#  '"295"': '"297"',
#  '"296"': '"298"',
#  '"297"': '"299"',
#  '"298"': '"300"',
#  '"306"': '"305"',
#  '"307"': '"302"',
#  '"309"': '"304"',
#  '"310"': '"306"',
#  '"311"': '"307"',
#  '"312"': '"308"',
#  '"313"': '"309"',
#  '"314"': '"309"',
#  '"315"': '"310"',
#  '"316"': '"311"',
#  '"317"': '"312"',
#  '"318"': '"313"',
#  '"319"': '"314"',
#  '"320"': '"315"',
#  '"321"': '"316"',
#  '"322"': '"317"',
#  '"323"': '"318"',
#  '"324"': '"319"',
#  '"325"': '"320"',
#  '"326"': '"321"',
#  '"327"': '"322"',
#  '"328"': '"323"',
#  '"329"': '"324"',
#  '"330"': '"325"',
#  '"331"': '"326"',
#  '"332"': '"327"',
#  '"333"': '"328"',
#  '"334"': '"329"',
#  '"335"': '"330"',
#  '"336"': '"331"',
#  '"337"': '"332"',
#  '"338"': '"333"',
#  '"339"': '"334"',
#  '"340"': '"335"',
#  '"341"': '"336"',
#  '"342"': '"337"',
#  '"343"': '"338"',
#  '"344"': '"339"',
#  '"345"': '"340"',
#  '"346"': '"341"',
#  '"347"': '"342"',
#  '"348"': '"343"',
#  '"349"': '"344"',
#  '"350"': '"345"',
#  '"351"': '"346"',
#  '"352"': '"347"',
#  '"353"': '"348"',
#  '"354"': '"349"',
#  '"355"': '"350"',
#  '"356"': '"351"',
#  '"357"': '"352"',
#  '"358"': '"353"',
#  '"359"': '"354"',
#  '"360"': '"355"',
#  '"361"': '"356"',
#  '"362"': '"357"',
#  '"363"': '"358"',
#  '"364"': '"359"',
#  '"365"': '"360"',
#  '"366"': '"361"',
#  '"367"': '"362"',
#  '"368"': '"363"',
#  '"369"': '"364"',
#  '"370"': '"365"',
#  '"371"': '"366"',
#  '"372"': '"367"',
#  '"373"': '"368"',
#  '"374"': '"369"',
#  '"375"': '"370"',
#  '"376"': '"371"',
#  '"377"': '"372"',
#  '"378"': '"373"',
#  '"379"': '"374"',
#  '"380"': '"375"',
#  '"381"': '"376"',
#  '"382"': '"377"',
#  '"383"': '"378"',
#  '"384"': '"379"',
#  '"385"': '"379"',
#  '"386"': '"379"',
#  '"387"': '"380"',
#  '"388"': '"381"',
#  '"389"': '"382"',
#  '"390"': '"383"',
#  '"391"': '"384"',
#  '"392"': '"385"',
#  '"393"': '"386"',
#  '"394"': '"386"',
#  '"395"': '"387"',
#  '"396"': '"388"',
#  '"397"': '"389"',
#  '"398"': '"390"',
#  '"399"': '"391"',
#  '"402"': '"394"',
#  '"403"': '"395"',
#  '"405"': '"397"',
#  '"406"': '"398"',
#  '"407"': '"399"',
#  '"408"': '"400"',
#  '"409"': '"401"',
#  '"410"': '"402"',
#  '"411"': '"403"',
#  '"412"': '"404"',
#  '"413"': '"405"',
#  '"414"': '"406"',
#  '"415"': '"407"',
#  '"416"': '"408"',
#  '"417"': '"409"',
#  '"418"': '"410"',
#  '"419"': '"411"',
#  '"420"': '"412"',
#  '"421"': '"413"',
#  '"422"': '"414"',
#  '"423"': '"415"',
#  '"424"': '"416"',
#  '"425"': '"417"',
#  '"426"': '"418"',
#  '"427"': '"419"',
#  '"428"': '"420"',
#  '"431"': '"423"',
#  '"432"': '"424"',
#  '"433"': '"425"',
#  '"434"': '"426"',
#  '"435"': '"427"',
#  '"436"': '"428"',
#  '"437"': '"429"',
#  '"438"': '"430"',
#  '"439"': '"431"',
#  '"440"': '"432"',
#  '"441"': '"433"',
#  '"442"': '"434"',
#  '"443"': '"435"',
#  '"444"': '"436"',
#  '"445"': '"437"',
#  '"446"': '"438"',
#  '"447"': '"439"',
#  '"448"': '"440"',
#  '"449"': '"441"',
#  '"450"': '"442"',
#  '"451"': '"443"',
#  '"452"': '"444"',
#  '"453"': '"445"',
#  '"454"': '"446"',
#  '"455"': '"447"',
#  '"456"': '"448"',
#  '"457"': '"449"',
#  '"458"': '"450"',
#  '"459"': '"451"',
#  '"460"': '"452"',
#  '"461"': '"453"',
#  '"462"': '"454"',
#  '"463"': '"455"',
#  '"464"': '"456"',
#  '"465"': '"457"',
#  '"466"': '"458"',
#  '"467"': '"459"',
#  '"468"': '"460"',
#  '"469"': '"461"',
#  '"470"': '"462"',
#  '"471"': '"463"',
#  '"472"': '"464"',
#  '"473"': '"465"',
#  '"474"': '"466"',
#  '"475"': '"467"',
#  '"476"': '"468"',
#  '"477"': '"469"',
#  '"478"': '"470"',
#  '"479"': '"471"',
#  '"480"': '"472"',
#  '"481"': '"473"',
#  '"482"': '"474"',
#  '"483"': '"475"',
#  '"484"': '"476"',
#  '"485"': '"477"',
#  '"486"': '"478"',
#  '"487"': '"479"',
#  '"488"': '"480"',
#  '"489"': '"481"',
#  '"490"': '"482"',
#  '"491"': '"483"',
#  '"492"': '"484"',
#  '"493"': '"485"',
#  '"494"': '"486"',
#  '"495"': '"487"',
#  '"496"': '"488"',
#  '"497"': '"489"',
#  '"498"': '"490"',
#  '"499"': '"491"',
#  '"500"': '"492"',
#  '"501"': '"493"',
#  '"502"': '"494"',
#  '"503"': '"495"',
#  '"504"': '"496"',
#  '"505"': '"497"',
#  '"506"': '"498"',
#  '"507"': '"499"',
#  '"508"': '"500"',
#  '"509"': '"501"',
#  '"510"': '"502"',
#  '"511"': '"503"',
#  '"512"': '"504"',
#  '"513"': '"505"',
#  '"514"': '"506"',
#  '"515"': '"507"',
#  '"516"': '"508"',
#  '"517"': '"509"',
#  '"518"': '"510"',
#  '"519"': '"511"',
#  '"520"': '"512"',
#  '"521"': '"513"',
#  '"522"': '"514"',
#  '"523"': '"515"',
#  '"524"': '"516"',
#  '"525"': '"517"',
#  '"526"': '"518"',
#  '"527"': '"519"',
#  '"528"': '"520"',
#  '"529"': '"521"',
#  '"530"': '"522"',
#  '"531"': '"523"',
#  '"532"': '"524"',
#  '"533"': '"525"',
#  '"534"': '"526"',
#  '"535"': '"527"',
#  '"536"': '"528"',
#  '"537"': '"529"',
#  '"538"': '"530"',
#  '"539"': '"531"',
#  '"540"': '"532"',
#  '"541"': '"533"',
#  '"542"': '"534"',
#  '"543"': '"535"',
#  '"544"': '"536"',
#  '"545"': '"537"',
#  '"546"': '"538"',
#  '"547"': '"539"',
#  '"548"': '"540"',
#  '"549"': '"541"',
#  '"550"': '"542"',
#  '"551"': '"543"',
#  '"552"': '"544"',
#  '"553"': '"545"',
#  '"554"': '"546"',
#  '"555"': '"547"',
#  '"556"': '"548"',
#  '"557"': '"549"',
#  '"558"': '"550"',
#  '"559"': '"551"',
#  '"560"': '"552"',
#  '"561"': '"553"',
#  '"562"': '"554"',
#  '"563"': '"555"',
#  '"564"': '"556"',
#  '"565"': '"557"',
#  '"566"': '"558"',
#  '"567"': '"559"',
#  '"568"': '"560"',
#  '"569"': '"561"',
#  '"570"': '"562"',
#  '"571"': '"563"',
#  '"572"': '"564"',
#  '"573"': '"565"',
#  '"574"': '"566"',
#  '"575"': '"567"',
#  '"576"': '"568"',
#  '"577"': '"569"',
#  '"578"': '"570"',
#  '"579"': '"571"',
#  '"580"': '"572"',
#  '"581"': '"573"',
#  '"582"': '"574"',
#  '"583"': '"575"',
#  '"584"': '"576"',
#  '"585"': '"577"',
#  '"586"': '"578"',
#  '"587"': '"579"',
#  '"588"': '"580"',
#  '"589"': '"581"',
#  '"590"': '"582"',
#  '"591"': '"583"',
#  '"592"': '"584"',
#  '"593"': '"585"',
#  '"594"': '"586"',
#  '"595"': '"587"',
#  '"596"': '"588"',
#  '"597"': '"589"',
#  '"598"': '"590"',
#  '"599"': '"591"',
#  '"600"': '"592"',
#  '"601"': '"593"',
#  '"602"': '"594"',
#  '"603"': '"595"',
#  '"604"': '"596"',
#  '"605"': '"597"',
#  '"606"': '"598"',
#  '"607"': '"599"',
#  '"608"': '"600"',
#  '"612"': '"3"',
#  '"613"': '"603"',
#  '"614"': '"604"',
#  '"615"': '"605"',
#  '"616"': '"606"',
#  '"617"': '"607"',
#  '"618"': '"608"',
#  '"619"': '"609"',
#  '"620"': '"610"',
#  '"621"': '"611"',
#  '"622"': '"612"',
#  '"623"': '"613"',
#  '"624"': '"614"',
#  '"625"': '"615"',
#  '"626"': '"616"',
#  '"627"': '"617"',
#  '"628"': '"618"',
#  '"629"': '"619"',
#  '"630"': '"620"',
#  '"631"': '"621"',
#  '"632"': '"622"',
#  '"633"': '"623"',
#  '"634"': '"624"',
#  '"635"': '"625"',
#  '"636"': '"626"',
#  '"637"': '"627"',
#  '"638"': '"628"',
#  '"639"': '"629"',
#  '"640"': '"630"',
#  '"641"': '"631"',
#  '"642"': '"632"',
#  '"643"': '"633"',
#  '"644"': '"634"',
#  '"645"': '"635"',
#  '"646"': '"636"',
#  '"647"': '"637"',
#  '"648"': '"638"',
#  '"649"': '"639"',
#  '"650"': '"640"',
#  '"651"': '"641"',
#  '"652"': '"642"',
#  '"653"': '"643"',
#  '"654"': '"644"',
#  '"655"': '"645"',
#  '"656"': '"646"',
#  '"657"': '"647"',
#  '"658"': '"648"',
#  '"659"': '"649"',
#  '"660"': '"650"',
#  '"661"': '"651"',
#  '"662"': '"652"',
#  '"663"': '"653"',
#  '"664"': '"654"',
#  '"665"': '"655"',
#  '"666"': '"656"',
#  '"667"': '"657"',
#  '"668"': '"658"',
#  '"669"': '"659"',
#  '"670"': '"660"',
#  '"671"': '"661"',
#  '"672"': '"662"',
#  '"673"': '"663"',
#  '"674"': '"664"',
#  '"675"': '"665"',
#  '"676"': '"666"',
#  '"677"': '"667"',
#  '"678"': '"668"',
#  '"679"': '"669"',
#  '"680"': '"670"',
#  '"681"': '"671"',
#  '"682"': '"672"',
#  '"683"': '"673"',
#  '"684"': '"674"',
#  '"685"': '"675"',
#  '"686"': '"676"',
#  '"687"': '"677"',
#  '"688"': '"678"',
#  '"689"': '"679"',
#  '"690"': '"680"',
#  '"691"': '"681"',
#  '"692"': '"682"',
#  '"693"': '"683"',
#  '"694"': '"684"',
#  '"695"': '"685"',
#  '"696"': '"686"',
#  '"697"': '"687"',
#  '"698"': '"688"',
#  '"699"': '"689"',
#  '"700"': '"690"',
#  '"701"': '"691"',
#  '"702"': '"692"',
#  '"703"': '"693"',
#  '"704"': '"694"',
#  '"705"': '"695"',
#  '"706"': '"696"',
#  '"707"': '"697"',
#  '"708"': '"698"',
#  '"709"': '"699"',
#  '"710"': '"700"',
#  '"711"': '"701"',
#  '"712"': '"702"',
#  '"713"': '"703"',
#  '"714"': '"704"',
#  '"715"': '"705"',
#  '"716"': '"706"',
#  '"717"': '"707"',
#  '"718"': '"708"',
#  '"719"': '"709"',
#  '"720"': '"710"',
#  '"721"': '"711"',
#  '"722"': '"712"',
#  '"723"': '"713"',
#  '"724"': '"714"',
#  '"725"': '"715"',
#  '"726"': '"716"',
#  '"727"': '"717"',
#  '"728"': '"718"',
#  '"729"': '"719"',
#  '"730"': '"720"',
#  '"731"': '"721"',
#  '"732"': '"722"',
#  '"733"': '"723"',
#  '"734"': '"724"',
#  '"735"': '"725"',
#  '"736"': '"726"',
#  '"737"': '"727"',
#  '"738"': '"728"',
#  '"739"': '"729"',
#  '"740"': '"730"',
#  '"741"': '"731"',
#  '"742"': '"732"',
#  '"743"': '"733"',
#  '"744"': '"734"',
#  '"745"': '"735"',
#  '"746"': '"736"',
#  '"747"': '"737"',
#  '"748"': '"738"',
#  '"749"': '"739"',
#  '"750"': '"740"',
#  '"751"': '"741"',
#  '"752"': '"742"',
#  '"753"': '"743"',
#  '"754"': '"744"',
#  '"755"': '"745"',
#  '"756"': '"746"',
#  '"757"': '"747"',
#  '"758"': '"748"',
#  '"759"': '"749"',
#  '"760"': '"750"',
#  '"761"': '"751"',
#  '"762"': '"752"',
#  '"763"': '"753"',
#  '"764"': '"754"',
#  '"765"': '"755"',
#  '"766"': '"756"',
#  '"767"': '"757"',
#  '"768"': '"758"',
#  '"769"': '"759"',
#  '"770"': '"760"',
#  '"771"': '"761"',
#  '"772"': '"762"',
#  '"773"': '"763"',
#  '"774"': '"764"',
#  '"775"': '"765"',
#  '"776"': '"766"',
#  '"777"': '"767"',
#  '"778"': '"768"',
#  '"779"': '"769"',
#  '"780"': '"770"',
#  '"781"': '"771"',
#  '"782"': '"772"',
#  '"783"': '"773"',
#  '"784"': '"774"',
#  '"785"': '"775"',
#  '"786"': '"776"',
#  '"787"': '"777"',
#  '"788"': '"778"',
#  '"789"': '"779"',
#  '"790"': '"780"',
#  '"791"': '"781"',
#  '"792"': '"782"',
#  '"793"': '"783"',
#  '"794"': '"784"',
#  '"795"': '"785"',
#  '"796"': '"786"',
#  '"797"': '"787"',
#  '"798"': '"788"',
#  '"799"': '"789"',
#  '"800"': '"790"',
#  '"801"': '"791"',
#  '"802"': '"792"',
#  '"803"': '"793"',
#  '"804"': '"794"',
#  '"805"': '"795"',
#  '"806"': '"796"',
#  '"807"': '"797"',
#  '"808"': '"798"',
#  '"809"': '"799"',
#  '"810"': '"800"',
#  '"811"': '"801"',
#  '"812"': '"802"',
#  '"813"': '"803"',
#  '"814"': '"804"',
#  '"815"': '"805"',
#  '"816"': '"806"',
#  '"817"': '"807"',
#  '"818"': '"808"',
#  '"819"': '"809"',
#  '"820"': '"810"',
#  '"821"': '"811"',
#  '"822"': '"812"',
#  '"823"': '"813"',
#  '"824"': '"814"',
#  '"825"': '"815"',
#  '"826"': '"816"',
#  '"827"': '"817"',
#  '"828"': '"818"',
#  '"829"': '"819"',
#  '"830"': '"820"',
#  '"831"': '"821"',
#  '"832"': '"822"',
#  '"833"': '"823"',
#  '"834"': '"824"',
#  '"835"': '"825"',
#  '"836"': '"826"',
#  '"837"': '"827"',
#  '"838"': '"828"',
#  '"839"': '"829"',
#  '"840"': '"830"',
#  '"841"': '"831"',
#  '"842"': '"832"',
#  '"843"': '"833"',
#  '"844"': '"834"',
#  '"845"': '"835"',
#  '"846"': '"836"',
#  '"847"': '"837"',
#  '"848"': '"838"',
#  '"849"': '"839"',
#  '"850"': '"840"',
#  '"851"': '"841"',
#  '"852"': '"842"',
#  '"853"': '"843"',
#  '"854"': '"844"',
#  '"855"': '"845"',
#  '"856"': '"846"',
#  '"857"': '"847"',
#  '"858"': '"848"',
#  '"859"': '"849"',
#  '"860"': '"850"',
#  '"861"': '"851"',
#  '"862"': '"852"',
#  '"863"': '"853"',
#  '"864"': '"854"',
#  '"865"': '"855"',
#  '"866"': '"856"',
#  '"867"': '"857"',
#  '"868"': '"858"',
#  '"869"': '"859"',
#  '"870"': '"860"',
#  '"871"': '"861"',
#  '"872"': '"862"',
#  '"873"': '"863"',
#  '"874"': '"864"',
#  '"875"': '"865"',
#  '"876"': '"866"',
#  '"877"': '"867"',
#  '"878"': '"868"',
#  '"879"': '"869"',
#  '"880"': '"870"',
#  '"881"': '"871"',
#  '"882"': '"872"',
#  '"883"': '"873"',
#  '"884"': '"874"',
#  '"885"': '"875"',
#  '"886"': '"876"',
#  '"887"': '"877"',
#  '"888"': '"878"',
#  '"889"': '"879"',
#  '"890"': '"880"',
#  '"891"': '"881"',
#  '"892"': '"882"',
#  '"893"': '"883"',
#  '"894"': '"884"',
#  '"895"': '"885"',
#  '"896"': '"886"',
#  '"897"': '"887"',
#  '"898"': '"888"',
#  '"899"': '"889"',
#  '"900"': '"890"',
#  '"901"': '"891"',
#  '"902"': '"892"',
#  '"903"': '"893"',
#  '"904"': '"894"',
#  '"905"': '"895"',
#  '"906"': '"896"',
#  '"907"': '"897"',
#  '"908"': '"898"',
#  '"909"': '"899"',
#  '"910"': '"900"',
#  '"911"': '"901"',
#  '"912"': '"902"',
#  '"913"': '"903"',
#  '"914"': '"904"',
#  '"915"': '"905"',
#  '"916"': '"906"',
#  '"917"': '"907"',
#  '"918"': '"908"',
#  '"919"': '"909"',
#  '"920"': '"910"',
#  '"921"': '"911"',
#  '"922"': '"912"',
#  '"923"': '"913"',
#  '"924"': '"914"',
#  '"925"': '"915"',
#  '"926"': '"916"',
#  '"927"': '"917"',
#  '"928"': '"918"',
#  '"929"': '"919"',
#  '"930"': '"920"',
#  '"931"': '"921"',
#  '"932"': '"922"',
#  '"933"': '"923"',
#  '"934"': '"924"',
#  '"935"': '"925"',
#  '"936"': '"926"',
#  '"937"': '"927"',
#  '"938"': '"928"',
#  '"939"': '"929"',
#  '"940"': '"930"',
#  '"941"': '"931"',
#  '"942"': '"932"',
#  '"943"': '"933"',
#  '"944"': '"934"',
#  '"945"': '"935"',
#  '"946"': '"936"',
#  '"947"': '"937"',
#  '"948"': '"938"',
#  '"949"': '"939"',
#  '"950"': '"940"',
#  '"951"': '"941"',
#  '"952"': '"942"',
#  '"953"': '"943"',
#  '"954"': '"944"',
#  '"955"': '"945"',
#  '"956"': '"946"',
#  '"957"': '"947"',
#  '"958"': '"948"',
#  '"959"': '"949"',
#  '"960"': '"950"',
#  '"961"': '"951"',
#  '"962"': '"952"',
#  '"963"': '"953"',
#  '"964"': '"954"',
#  '"965"': '"955"',
#  '"966"': '"956"',
#  '"967"': '"957"',
#  '"968"': '"958"',
#  '"969"': '"959"',
#  '"970"': '"960"',
#  '"971"': '"961"',
#  '"972"': '"962"',
#  '"973"': '"963"',
#  '"974"': '"964"',
#  '"975"': '"965"',
#  '"976"': '"966"',
#  '"977"': '"967"',
#  '"978"': '"968"',
#  '"979"': '"969"',
#  '"980"': '"970"',
#  '"981"': '"971"',
#  '"982"': '"972"',
#  '"983"': '"973"',
#  '"984"': '"974"',
#  '"985"': '"975"',
#  '"986"': '"976"',
#  '"987"': '"977"',
#  '"988"': '"978"',
#  '"989"': '"979"',
#  '"990"': '"980"',
#  '"991"': '"981"',
#  '"992"': '"982"',
#  '"993"': '"983"',
#  '"994"': '"984"',
#  '"995"': '"985"',
#  '"996"': '"986"',
#  '"997"': '"987"',
#  '"998"': '"988"',
#  '"999"': '"989"',
#  '"1000"': '"990"',
#  '"1001"': '"991"',
#  '"1002"': '"992"',
#  '"1003"': '"993"',
#  '"1004"': '"994"',
#  '"1005"': '"995"',
#  '"1006"': '"996"',
#  '"1007"': '"997"',
#  '"1008"': '"998"',
#  '"1009"': '"999"',
#  '"1010"': '"1000"',
#  '"1011"': '"1001"',
#  '"1012"': '"1002"',
#  '"1013"': '"1003"',
#  '"1014"': '"1004"',
#  '"1015"': '"1005"',
#  '"1016"': '"1006"',
#  '"1017"': '"1007"',
#  '"1018"': '"1008"',
#  '"1019"': '"1009"',
#  '"1020"': '"1010"',
#  '"1021"': '"1011"',
#  '"1022"': '"1012"',
#  '"1023"': '"1013"',
#  '"1024"': '"1014"',
#  '"1025"': '"1015"',
#  '"1026"': '"1016"',
#  '"1027"': '"1017"',
#  '"1028"': '"1018"',
#  '"1029"': '"1019"',
#  '"1030"': '"1020"',
#  '"1031"': '"1021"',
#  '"1032"': '"1022"',
#  '"1033"': '"1023"',
#  '"1034"': '"1024"',
#  '"1035"': '"1025"',
#  ...}

# %%
final_data = [['note_id', 'diary_id', 'author_id', 'note_date', 'people']]

# %%
for name in names_all:
    #print(name[2])
    final_data.append([name[0], name[1], diaryid_persid[name[1]], name[2], name[3]])

# %%
final_data[0]
# Out:
# ['note_id', 'diary_id', 'author_id', 'note_date', 'people']

# %%
with open("rec_persons.csv", 'w', encoding='utf-8') as f:
    for header in final_data[0]:
        if header != final_data[0][-1]:
            f.write(str(header)+',#')
        if header == final_data[0][-1]:
            f.write(str(header)+'\n')
    for data in final_data[1:]:
        if len(data[-1]) != 0:
            for content in data:
                if content != data[-1]:
                    f.write(str(content)+',#')
                if content == data[-1]:
                    f.write('"')
                    for tup in content:
                        if tup != content[-1]:
                            f.write(str(tup[0])+'->'+str(tup[1])+',')
                        else:
                            f.write(str(tup[0])+'->'+str(tup[1])+'"\n')
        else:
            for content in data:
                if content != data[-1]:
                    f.write(str(content)+',#')
                if content == data[-1]:
                    f.write('\n')

# %%
#прогнать на полном файле, посчитать самые частые имена, сравнить с прошлгодней курсовой
